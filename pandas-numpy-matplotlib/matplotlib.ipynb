# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data=np.arange(10)
plt.plot(data)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig=plt.figure()
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
## draws on last plot  in last fig
plt.plot(np.random.randn(50).cumsum(),'k--')

# %%
ax1.hist(np.random.randn(100),bins=20,color='k',alpha=0.3)
# Out:
# (array([ 1.,  1.,  2.,  5.,  2.,  3.,  4.,  9.,  6.,  4., 15.,  9., 10.,
#          4.,  6.,  8.,  4.,  2.,  3.,  2.]),
#  array([-3.08117581, -2.79480628, -2.50843675, -2.22206723, -1.9356977 ,
#         -1.64932817, -1.36295864, -1.07658912, -0.79021959, -0.50385006,
#         -0.21748054,  0.06888899,  0.35525852,  0.64162805,  0.92799757,
#          1.2143671 ,  1.50073663,  1.78710616,  2.07347568,  2.35984521,
#          2.64621474]),
#  <a list of 20 Patch objects>)

# %%
ax2.scatter(np.arange(30),np.arange(30)+3*np.random.randn(30))

# %%
fig,axes=plt.subplots(2,3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axes[1,2].plot(np.arange(30))

# %%
fig,axes=plt.subplots(2,2,sharex=True,sharey=True)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.randn(500),bins=50,color='r',alpha=0.5)
plt.subplots_adjust(wspace=0,hspace=0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(np.random.randn(30).cumsum(),'ko--')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(np.random.randn(30).cumsum(),color='r',marker='o',linestyle='--')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
data=np.random.randn(30).cumsum()
plt.plot(data,color='r',linestyle='--',label='default')
plt.plot(data,color='g',linestyle='-',drawstyle='steps-post',label='steps-post')
plt.legend(loc='best')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
ax.plot(np.random.randn(1000).cumsum())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax.set_xticks([0,250,500,750,1000])
ax.set_xticklabels(['one','two','three','four','five'],rotation=30,fontsize='small')
# Out:
# [Text(0, 0, 'one'),
#  Text(0, 0, 'two'),
#  Text(0, 0, 'three'),
#  Text(0, 0, 'four'),
#  Text(0, 0, 'five')]

# %%
ax.set_title('my plot')
ax.set_xlabel('count')
# Out:
# Text(0.5, 0, 'count')

# %%
props={'title':'my first plot','xlabel':'stages'}
ax.set(**props)
# Out:
# [Text(0.5, 0, 'stages'), Text(0.5, 1.0, 'my first plot')]

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
ax.plot(np.random.randn(1000).cumsum(),'b',label='one')
ax.plot(np.random.randn(1000).cumsum(),'r--',label='two')
ax.plot(np.random.randn(1000).cumsum(),'g-',label='three')
plt.legend(loc='best')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
rect=plt.Rectangle((0.2,0.75),0.4,0.15,color='k',alpha=0.3)
circle=plt.Circle((0.7,0.2),0.15,color='b',alpha=0.3)
pgon=plt.Polygon([[0.15,0.15],[0.35,0.4],[0.2,0.6]],color='g',alpha=0.5)
ax.add_patch(rect)
ax.add_patch(circle)
ax.add_patch(pgon)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig.savefig('test.pdf')

# %%
plt.savefig('fig.png',dpi=400,bbox_inches='tight',facecolor='y')

# %%
import pandas as pd
df=pd.DataFrame(np.random.randn(10,4).cumsum(0),columns=['A','B','C','D'],index=np.arange(0,100,10))
df
# Out:
#            A         B         C         D
# 0  -1.286076 -0.163568  0.624587  1.210808
# 10 -1.077133 -0.383035  1.709825  1.769967
# 20  0.462807 -1.853448  2.892118  2.365497
# 30  0.524152 -2.102032  3.675867  2.780275
# 40  0.159655 -1.534925  2.262439  3.500875
# 50  2.005261 -1.646813  1.884266  3.124110
# 60  2.958491 -1.335628  1.586204  4.120664
# 70  2.248351 -2.126477  0.185846  4.716130
# 80  0.350021 -1.589559 -0.027751  4.433860
# 90  0.512510 -1.942694  1.006104  3.038697

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot(subplots='True')
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001C6527C1CC8>,
# ...
#       dtype=object)

# %%
fig,axes=plt.subplots(2,1)
data=pd.Series(np.random.rand(16),index=list('abcdefghijklmnop'))
data.plot.bar(ax=axes[0],color='k',alpha=0.7)
data.plot.barh(ax=axes[1],color='g',alpha=0.7)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df=pd.DataFrame(np.random.randn(6,4),index=['one','two','three','four','five','six'],columns=pd.Index(['A','B','C','D'],name='Genus'))
df.plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.bar(stacked='True')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.barh(stacked='True')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
df=pd.Series(np.random.randn(10000))
df.plot.hist(ax=ax1,bins=50)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
df=pd.Series(np.random.randn(10000))
df.plot.density()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
comp1=np.random.normal(0,1,size=200)
comp2=np.random.normal(10,2,size=200)
values=pd.Series(np.concatenate([comp1,comp2]))
values.plot.hist(bins=100)

# %%
import seaborn as sns
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
sns.distplot(values,ax=ax1,bins=100,color='k')
# Out:
# <img src="data:image/png;base64,..." width="640">
