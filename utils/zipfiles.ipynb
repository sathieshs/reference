# %%
from zipfile import ZipFile
import os
from os.path import basename
# create a ZipFile object


with ZipFile('code.zip', 'w') as zipObj:
   # Iterate over all the files in directory
   dirName=os.getcwd()
   for folderName, subfolders, filenames in os.walk(dirName):
       for filename in filenames:
           #create complete filepath of file in directory
           filePath = os.path.join(folderName, filename)
           # Add file to zip
           zipObj.write(filePath, basename(filePath))

# %%
def get_all_file_paths(directory):
  
    # initializing empty file paths list
    file_paths = []
  
    # crawling through directory and subdirectories
    for root, directories, files in os.walk(directory):
        for filename in files:
            # join the two strings in order to form the full filepath.
            filepath = os.path.join(root, filename)
            file_paths.append(filepath)
  
    # returning all file paths
    return file_paths
# Out:
# ['.\\collectfiles.py',
#  '.\\KNNFeatures.py',
#  '.\\zipfiles.ipynb',
#  '.\\__init__.py',
#  '.\\.idea\\.gitignore',
#  '.\\.idea\\misc.xml',
#  '.\\.idea\\modules.xml',
#  '.\\.idea\\utils.iml',
#  '.\\.idea\\workspace.xml',
#  '.\\.idea\\inspectionProfiles\\profiles_settings.xml',
#  '.\\.ipynb_checkpoints\\zipfiles-checkpoint.ipynb',
#  '.\\__pycache__\\KNNFeatures.cpython-310.pyc']

# %%
def zip_files(sourcedir=os.getcwd(),targetdir=os.getcwd(),target_file_name='ziped_data.zip',create_subfolders=True,allowed_extn=[],blacklisted_extn=[],blacklisted_files=[]):
    file_paths = get_all_file_paths(sourcedir)
    with ZipFile(os.path.join(targetdir,target_file_name), 'w') as zipObj:
       # Iterate over all the files in directory
       for file in file_paths:
        if(basename(file).split('.')[-1] in allowed_extn or len(allowed_extn)==0 or allowed_extn is None ):
            if(not (basename(file).split('.')[-1] in blacklisted_extn)):
                if(not(basename(file) in blacklisted_files)):
                       # Add file to zip
                    if create_subfolders:
                        zipObj.write(file, file)
                    else:
                        zipObj.write(file, basename(file))
#zip_files(sourcedir=r'C:\Users\sathi\Desktop\coursera\tensrflow advanced techniques',create_subfolders=True,blacklisted_extn=['mp4','download'])

# %%
def createfolder_with_files(**kwargs):
    zip_files(**kwargs)
    foldername=os.getcwd()
    for key, value in kwargs.items():
        if key=='targetdir':
            foldername=value
    with ZipFile(os.path.join(foldername,'ziped_data.zip'), 'r') as zip:
        # printing all the contents of the zip file
        zip.printdir()
        # extracting all the files
        print('Extracting all the files now...')
        zip.extractall(os.path.join(foldername,'ziped_data_folder'))
        print('Extraction done')
            
createfolder_with_files(sourcedir=r'C:\Users\sathi\Desktop\coursera\tensrflow advanced techniques',create_subfolders=True,blacklisted_extn=['mp4','download'],blacklisted_files=['Untitled-checkpoint.ipynb','Untitled.ipynb'])
# Out:
# File Name                                             Modified             Size
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Image Segmentation Overview/code/C3W3_Assignment.ipynb 2022-01-02 11:11:54        53621
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Image Segmentation Overview/code/C3_W3_Lab_1_VGG16_FCN8_CamVid.ipynb 2022-01-02 11:10:44        43361
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Image Segmentation Overview/code/C3_W3_Lab_2_OxfordPets_UNet.ipynb 2022-01-02 11:11:04        34751
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Image Segmentation Overview/code/C3_W3_Lab_3_Mask_RCNN_ImageSegmentation.ipynb 2022-01-02 11:11:30        15942
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Introduction to Computer Vision/code/C3W1_Assignment.ipynb 2022-01-02 10:41:10       204816
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Introduction to Computer Vision/code/C3_W1_Lab_1_transfer_learning_cats_dogs.ipynb 2022-01-02 10:35:14        18065
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Introduction to Computer Vision/code/C3_W1_Lab_2_Transfer_Learning_CIFAR_10.ipynb 2022-01-02 10:37:04        13434
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Introduction to Computer Vision/code/C3_W1_Lab_3_Object_Localization.ipynb 2022-01-02 10:40:20        31638
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Object Detection/code/C3W2_Assignment.ipynb 2022-01-02 11:00:08       112528
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Object Detection/code/C3_W2_Lab_1_Simple_Object_Detection.ipynb 2022-01-02 10:58:58        12526
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Object Detection/code/C3_W2_Lab_2_Object_Detection.ipynb 2022-01-02 10:59:20        21096
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/code/C3W4_Assignment.ipynb 2022-01-02 13:06:04        23371
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/code/C3_W4_Lab_1_FashionMNIST_CAM.ipynb 2022-01-02 13:04:46        19886
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/code/C3_W4_Lab_2_CatsDogs_CAM.ipynb 2022-01-02 13:05:00        11867
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/code/C3_W4_Lab_3_Saliency.ipynb 2022-01-02 13:05:14        11367
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/code/C3_W4_Lab_4_GradCam.ipynb 2022-01-02 13:05:30        17614
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/html/References _ Coursera.html 2022-01-02 13:07:52       896129
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/html/References _ Coursera_files/0 2022-01-02 13:07:50            0
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/html/References _ Coursera_files/458359.gif 2022-01-02 13:07:52           37
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/html/References _ Coursera_files/946401778754875 2022-01-02 13:07:32       312581
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/html/References _ Coursera_files/activityi.html 2022-01-02 13:07:52         1087
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/html/References _ Coursera_files/adsct 2022-01-02 13:07:50           31
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/html/References _ Coursera_files/allStyles.cdea49abeb63bbde60b8.css 2022-01-02 13:07:34      1043631
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/html/References _ Coursera_files/cart_badged.png 2022-01-02 13:07:50          514
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/html/References _ Coursera_files/dc_pre=COrRwLirkvUCFaOR5godLD4HEA 2022-01-02 13:07:52           42
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/html/References _ Coursera_files/dnsfeed 2022-01-02 13:07:34          188
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/html/References _ Coursera_files/f(1).txt 2022-01-02 13:07:42         2710
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/html/References _ Coursera_files/f.txt 2022-01-02 13:07:32        37921
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/html/References _ Coursera_files/js 2022-01-02 13:07:40        89400
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/html/References _ Coursera_files/jsp 2022-01-02 13:07:40          148
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/html/References _ Coursera_files/Navigation-Branding-Image-3.png 2022-01-02 13:07:50          702
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/html/References _ Coursera_files/pixel.html 2022-01-02 13:07:52          184
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/html/References _ Coursera_files/saved_resource 2022-01-02 13:07:50        13913
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/html/References _ Coursera_files/saved_resource(1).html 2022-01-02 13:07:52          149
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/html/References _ Coursera_files/saved_resource.html 2022-01-02 13:07:52          149
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Advanced Computer Vision with TensorFlow/Visualization and Interpretability/html/References _ Coursera_files/up.html 2022-01-02 13:07:52          361
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Custom Training/assignment/C2W2_Assignment-checkpoint.ipynb 2021-12-30 19:08:02        30842
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Custom Training/assignment/C2W2_Assignment.ipynb 2021-12-30 19:08:02        30842
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Custom Training/assignment/code.zip 2021-12-30 19:08:02            0
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Custom Training/assignment/data.csv 2021-12-30 19:08:02        19889
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Custom Training/assignment/saved_model.pb 2021-12-30 19:08:02        61727
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Custom Training/assignment/variables.data-00000-of-00001 2021-12-30 19:08:02        40473
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Custom Training/assignment/variables.index 2021-12-30 19:08:02          514
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Custom Training/code/C2_W2_Lab_1_training-basics-checkpoint.ipynb 2021-12-30 19:05:26        10930
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Custom Training/code/C2_W2_Lab_1_training-basics.ipynb 2021-12-30 19:05:26        10930
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Custom Training/code/C2_W2_Lab_2_training-categorical-checkpoint.ipynb 2021-12-30 19:05:26        16968
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Custom Training/code/C2_W2_Lab_2_training-categorical.ipynb 2021-12-30 19:05:26        16968
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Custom Training/code/dataset_info.json 2021-12-30 19:05:26         2829
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Custom Training/code/fashion_mnist-test.tfrecord-00000-of-00001 2021-12-30 19:05:26      5630824
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Custom Training/code/fashion_mnist-train.tfrecord-00000-of-00001 2021-12-30 19:05:26     33677636
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Custom Training/code/image.image.json 2021-12-30 19:05:26           48
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Custom Training/code/label.labels.txt 2021-12-30 19:05:26           76
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Differentiation and Gradients/code/C2W1_Assignment.ipynb 2021-12-30 18:55:54        11650
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Differentiation and Gradients/code/C2_W1_Lab_1_basic-tensors.ipynb 2021-12-30 18:55:02         7473
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Differentiation and Gradients/code/C2_W1_Lab_2_gradient-tape-basics.ipynb 2021-12-30 18:54:56        11327
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Distributed Training/code/C2W4_Assignment.ipynb 2021-12-31 10:32:46        30370
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Distributed Training/code/C2_W4_Lab_1_basic-mirrored-strategy-checkpoint.ipynb 2021-12-31 10:30:18         7492
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Distributed Training/code/C2_W4_Lab_1_basic-mirrored-strategy.ipynb 2021-12-31 10:30:16         7492
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Distributed Training/code/C2_W4_Lab_2_multi-GPU-mirrored-strategy-checkpoint.ipynb 2021-12-31 10:30:18        10927
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Distributed Training/code/C2_W4_Lab_2_multi-GPU-mirrored-strategy.ipynb 2021-12-31 10:30:16        10927
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Distributed Training/code/C2_W4_Lab_3_using-TPU-strategy-checkpoint.ipynb 2021-12-31 10:30:18        19103
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Distributed Training/code/C2_W4_Lab_3_using-TPU-strategy.ipynb 2021-12-31 10:30:16        19103
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Distributed Training/code/C2_W4_Lab_4_one-device-strategy-checkpoint.ipynb 2021-12-31 10:30:18         8933
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Distributed Training/code/C2_W4_Lab_4_one-device-strategy.ipynb 2021-12-31 10:30:16         8932
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Distributed Training/code/code.zip 2021-12-31 10:30:16            0
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Distributed Training/code/dataset_info.json 2021-12-31 10:30:18         2255
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Distributed Training/code/image.image.json 2021-12-31 10:30:16           48
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Distributed Training/code/mnist-test.tfrecord-00000-of-00001 2021-12-31 10:30:16      3310056
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Distributed Training/code/mnist-train.tfrecord-00000-of-00001 2021-12-31 10:30:18     19832042
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Graph Mode/code/C2W3_Assignment.ipynb 2021-12-31 10:20:00        24690
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Graph Mode/code/C2_W3_Lab_1_autograph-basics.ipynb 2021-12-31 10:17:20         3794
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom and Distributed Training with TensorFlow/Graph Mode/code/C2_W3_Lab_2-graphs-for-complex-code.ipynb 2021-12-31 10:17:24         7910
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Callbacks/code/C1_W5_Lab_1_exploring-callbacks-checkpoint.ipynb 2021-12-30 13:46:32        16651
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Callbacks/code/C1_W5_Lab_1_exploring-callbacks.ipynb 2021-12-30 13:46:32        16651
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Callbacks/code/C1_W5_Lab_2_custom-callbacks-checkpoint.ipynb 2021-12-30 13:46:32        13051
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Callbacks/code/C1_W5_Lab_2_custom-callbacks.ipynb 2021-12-30 13:46:32        13051
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Callbacks/code/dataset_info.json 2021-12-30 13:46:34         2227
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Callbacks/code/features.json 2021-12-30 13:46:34          629
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Callbacks/code/horses_or_humans-test.tfrecord-00000-of-00001 2021-12-30 13:46:32     11539007
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Callbacks/code/horses_or_humans-train.tfrecord-00000-of-00002 2021-12-30 13:46:34     74556150
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Callbacks/code/horses_or_humans-train.tfrecord-00001-of-00002 2021-12-30 13:46:34     74911794
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Callbacks/code/label.labels.txt 2021-12-30 13:46:34           14
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Custom Layers/code/C1W3_Assignment.ipynb 2021-12-30 13:04:32         7790
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Custom Layers/code/C1_W3_Lab_1_lambda-layer.ipynb 2021-12-30 13:01:56         4191
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Custom Layers/code/C1_W3_Lab_2_custom-dense-layer.ipynb 2021-12-30 13:02:02         5087
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Custom Layers/code/C1_W3_Lab_3_custom-layer-activation.ipynb 2021-12-30 13:02:06         4675
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Custom Layers/code/utils.py 2021-12-30 13:04:40         4109
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Custom loss functions/code/C1W2_Assignment.ipynb 2021-12-30 12:42:56         6839
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Custom loss functions/code/C1_W1_Lab_3_siamese-network.ipynb 2021-12-30 12:41:44        14224
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Custom loss functions/code/C1_W2_Lab_1_huber-loss.ipynb 2021-12-30 12:39:00         4152
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Custom loss functions/code/C1_W2_Lab_2_huber-object-loss.ipynb 2021-12-30 12:39:08         6020
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Custom loss functions/code/utils.py 2021-12-30 12:43:30         2248
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Custom Models/code/C1W4_Assignment.ipynb 2021-12-30 13:31:48        19411
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Custom Models/code/C1_W4_Lab_1_basic-model-checkpoint.ipynb 2021-12-30 13:18:40        31833
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Custom Models/code/C1_W4_Lab_1_basic-model.ipynb 2021-12-30 13:18:38         5407
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Custom Models/code/C1_W4_Lab_2_resnet-example-checkpoint.ipynb 2021-12-30 13:18:40         7054
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Custom Models/code/C1_W4_Lab_2_resnet-example.ipynb 2021-12-30 13:18:38         7054
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Custom Models/code/dataset_info.json 2021-12-30 13:18:38         2262
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Custom Models/code/image.image.json 2021-12-30 13:18:38           48
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Custom Models/code/mnist-test.tfrecord-00000-of-00001 2021-12-30 13:18:38      3310056
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Custom Models/code/mnist-train.tfrecord-00000-of-00001 2021-12-30 13:18:38     19832042
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Custom Models/code/utils.py 2021-12-30 13:31:30         9906
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Custom Models/code/VGG.png 2021-12-30 13:31:26        22419
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Functional APIs/code/C1W1_Assignment.ipynb 2021-12-30 12:22:24        38324
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Functional APIs/code/C1_W1_Lab_1_functional-practice.ipynb 2021-12-30 12:10:42         5032
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Functional APIs/code/C1_W1_Lab_2_multi-output.ipynb 2021-12-30 12:10:42         7775
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Functional APIs/code/C1_W1_Lab_3_siamese-network.ipynb 2021-12-30 12:10:40        14224
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Functional APIs/code/ENB2012_data.xlsx 2021-12-30 12:10:42        76189
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Functional APIs/code/utils.py 2021-12-30 12:24:16        11942
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Functional APIs/code/winequality-red.csv 2021-12-30 12:24:26        84199
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Custom Models, Layers, and Loss Functions with TensorFlow/Functional APIs/code/winequality-white.csv 2021-12-30 12:24:36       264426
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Generative Deep Learning with TensorFlow/AutoEncoders/code/C4W2_Assignment.ipynb 2022-01-02 13:48:32        10457
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Generative Deep Learning with TensorFlow/AutoEncoders/code/C4_W2_Lab_1_FirstAutoEncoder.ipynb 2022-01-02 13:47:18         7752
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Generative Deep Learning with TensorFlow/AutoEncoders/code/C4_W2_Lab_2_MNIST_Autoencoder.ipynb 2022-01-02 13:47:36         8596
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Generative Deep Learning with TensorFlow/AutoEncoders/code/C4_W2_Lab_3_MNIST_DeepAutoencoder.ipynb 2022-01-02 13:47:52         7978
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Generative Deep Learning with TensorFlow/AutoEncoders/code/C4_W2_Lab_4_FashionMNIST_CNNAutoEncoder.ipynb 2022-01-02 13:48:06        11726
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Generative Deep Learning with TensorFlow/AutoEncoders/code/C4_W2_Lab_5_FashionMNIST_NoisyCNNAutoEncoder.ipynb 2022-01-02 13:48:18        10664
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Generative Deep Learning with TensorFlow/GANs/code/C4W4_Assignment.ipynb 2022-01-02 13:59:48        18604
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Generative Deep Learning with TensorFlow/GANs/code/C4_W4_Lab_1_First_GAN.ipynb 2022-01-02 13:58:54        13832
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Generative Deep Learning with TensorFlow/GANs/code/C4_W4_Lab_2_First_DCGAN.ipynb 2022-01-02 13:59:10        13162
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Generative Deep Learning with TensorFlow/GANs/code/C4_W4_Lab_3_CelebA_GAN_Experiments.ipynb 2022-01-02 13:59:26        29130
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Generative Deep Learning with TensorFlow/GANs/html/References _ Coursera.html 2022-01-02 13:58:50       983586
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Generative Deep Learning with TensorFlow/GANs/html/References _ Coursera_files/allStyles.cdea49abeb63bbde60b8.css 2022-01-02 13:58:36      1043631
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Generative Deep Learning with TensorFlow/GANs/html/References _ Coursera_files/cart_badged.png 2022-01-02 13:58:50          514
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Generative Deep Learning with TensorFlow/GANs/html/References _ Coursera_files/Navigation-Branding-Image-4.png 2022-01-02 13:58:48          669
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Generative Deep Learning with TensorFlow/style transfer/code/C4W1_Assignment.ipynb 2022-01-02 13:43:12        31174
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Generative Deep Learning with TensorFlow/style transfer/code/C4_W1_Lab_1_Neural_Style_Transfer (1).ipynb 2022-01-02 13:42:40        43786
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Generative Deep Learning with TensorFlow/style transfer/code/C4_W1_Lab_1_Neural_Style_Transfer.ipynb 2022-01-02 13:42:14        43786
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Generative Deep Learning with TensorFlow/style transfer/code/C4_W1_Lab_2_Fast_NST.ipynb 2022-01-02 13:42:56         7666
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Generative Deep Learning with TensorFlow/Variational AutoEncoders/code/C4W3_Assignment.ipynb 2022-01-02 13:53:08        29167
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Generative Deep Learning with TensorFlow/Variational AutoEncoders/code/C4_W3_Lab_1_VAE_MNIST.ipynb 2022-01-02 13:52:40        24210
# Users/sathi/Desktop/coursera/tensrflow advanced techniques/Generative Deep Learning with TensorFlow/Variational AutoEncoders/code/vae_overview.png 2022-01-02 13:54:28       194669
# Extracting all the files now...
# Extraction done
